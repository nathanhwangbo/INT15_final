# %% [markdown]
# # INT15 FINAL PROJECT
#
# ## Due Date:  June 12, midnight

# %% [markdown]
# ## About the Project
# The final project is an opportunity to put all that you have learned in this course. Think of this project as a step towards building your portfolio that showcases your work, skills, and interests.
#
# The following two resources provide helpful guidelines for how to approach the project and structure your write-up:
# * _A Data Science Project Style Guide from Dataquest_: https://www.dataquest.io/blog/data-science-project-style-guide/
# * _Building a data science portfolio: Storytelling with data_: https://www.dataquest.io/blog/data-science-portfolio-project/
#
# Your task is to conduct a start-to-finish analysis of a real dataset. This will require many of the skills we have learned over the quarter: from manipulating data, exploratory analysis and dimension reduction, translating scientific questions into models and algorithms, basic regression and classification, and carefully crafted visualizations.  You should present your results in a clear and concise manner.
#
# This is a pair project (i.e. max of 2 people in a group).

# %% [markdown]
# <span style="color:red">
#     <h1> PROJECT TITLE GOES HERE </h1>
# </span>

# %% [markdown]
# <span style="color:blue">
# <h2> Names: Partner 1 and Partner 2 </h2>
# </span>

# %% [markdown]
# ## Dataset, Questions of Interest, and Exploratory Analysis
#
# We have provided a handful of vetted datasets that would make for interesting projects.  First, look over these datasets and decide which one is most interesting to you and your partner.  Identify some relevant preliminary questions to pursue with this dataset.
#
# Before starting data analysis, answer the following questions:
#
# * Are there missing values in the dataset? How do you know?
# * Are there any missing values that were filled in?
# * Which parts of the data were entered by a human?
#
# Take a look at the Quartz "bad data guide" for a more complete list of checks: https://github.com/Quartz/bad-data-guide

# %% [markdown]
# ## The Final Project Report
#
# Each group submits **one** report -- **make sure to add your partner to your group on Gradescope and okpy**.
#
# The maximum page limit (excluding the title page and appendices) for the project report is **6 pages**. The report should be prepared using 11pt or 12pt font size with 1-inch margins, on US letter paper.
#
# The final project report must be structured as follows:
#
# **1. Title Page:**
#
# Must include the title of your project, and the names of the group members.
#
# **2. Abstract (100 words or more):**
#
# Brief summary of your project, questions of interest and findings.
#
# **3. Introduction (200 words or more):**
#
# In this section you should describe
#
# (i) the relevant background of your topic, and,
#
# (ii) the motivation for your project i.e., why your readers should be interested.
#
# **4. Questions of Interest:**
#
# State clearly and concisely your questions of interest.
#
# **5. Data and Methods:**
# * Briefly state the source of your data and describe the relevant variables that you will use in your project.  Discuss which "principles of measurement" might be particularly relevant to your questions (distortion, relevance, precision, cost).
# * For each question of interest, state how you will attempt to answer that question. There is no need to describe the mathematical or statistical details of the methods.
# * (_Exploratory Analysis_) Exploratory plots of the data and numerical summaries are essential in beginning any analysis. At this stage, scatterplots, added variable plots, box-plots, etc. can give you a sense of relationships that exist between relevant variables.
#     * Will transformations be needed/useful for any of these variables?
#     * Can you use dimension reduction (PCA or an alternative) to identify interesting patterns?
#     * Are outliers and/or measurement error a concern?
#     * You should comment on your findings, particularly if there are interesting or counterintuitive observations to be made.
# * What inferential or predictive methods / models are you using (linear regression, classification methods, etc).  Consider using the `statsmodels` and `scikit-learn` libraries.
# * You are free to use methods not discussed in this class if you are comfortable doing so but you should clearly state the purpose of the method, what it does and how it fits into the ideas we've discussed in class (e.g., exploratory, dimension reduction, regression, classification, visualization, etc).

# %% [markdown]
# **6. Analysis, Results and Interpretation**
#
# In separate subsections, you should answer each of your questions of interest. Your narrative should include:
#
# * Important Details of the Analysis:
#      * Perform the analysis. Depending on the questions you want to answer, this will include various items from the following list:
#
# * Assumptions:
#      * Were your assumptions plausible? Why?
#      * Are there outliers?
#
# * Interpretation:
#      * What do your results mean for the questions you were trying to answer?
#          * What  were  two  or  three  of  the  most  interesting  features  you  came  across? Describe  the  process  of  finding  those  features.
#          * Describe  one  feature  you  thought  would  be useful, but turned out to be ineffective.
#      * Relevant plots with proper title, variable names, legends, etc. must be included within the body of the text. Plots should not be too small or too large. Make sure to number the figures and include informative captions.
#     * After conducting the analysis, you should give concrete (i.e. data-specific), accurate and complete interpretations of your results. These interpretations should involve a mix of  terminology, variable names and appropriate scientific units.
#
# * Discuss any ethical issues surrounding your data or analysis (1-2 paragraphs).
#     * What effects (positve/negative) could your results have?
#     * Who is it likely to affect?
#     * How is it likely to affect them?

# %% [markdown]
# ## Conclusions and Future Work (200 words)
#
# In this section you should summarize your findings based on your final model in clearly understandable, non-statistical terms. What is the main message produced by your analysis? There may also be additional questions that arise, problems you encounter, or possible extensions of your analysis that could be addressed here.
#
# Include any final comments and thoughts about your project. For example, do you trust your results? How general are your results, to what situations do they apply? Add any other comments that are relevant.

# %% [markdown]
# ## Grading Criteria
#
# Your grade on the project will be based on the following criteria:
#
# **1. Compatibility of Scientific Question and Analysis**
#
# Is the scientific question being addressed actually of interest, and were suitable tools employed?
#
# **2. Coherent Thought Process and Presentation of Results**
#
# * Does the analysis indicate a sound understanding of methods discussed in class? This is often best judged by the preliminary comments on the questions of interest as well as the conclusions made after the analysis.
# * Is the analysis presented in a clear, consistent, coherent style with the appropriately labeled requested components and visualizations?
#
# **3. Scope of the analysis and methods used**
#
# Did the analysis demonstrate a wide understanding of methodology and ideas presented throughout the quarter?
#
# **4. Reproducible results**
#
# Is it possible to reproduce the analysis and the visuals by executing the provided code?

# %% [markdown]
# ## Submission
#
# You are required to submit two files:
#
# 1. Submit your completed writeup as a PDF to gradescope.  You should address all of the components described above, adhering to the page limit, and include any figures and tables that are necessary. (Make sure to number figures and tables and include informative captions.)
#
# 2.  Submit a complete jupyter notebook with all of your analyses to the okpy server.  For your submission, use **this jupyter notebook** as a template (remove the instructions, replacing them with your analysis).  We should be able to reproduce all of your results by running your notebook.
#
# Before you submit the notebook, make sure that you select from the top menu `Kernel -> Restart & Clear Output` followed by `Cell -> Run All`. Verify that all computations execute correctly. There should be no errors when we run your notebook.

# %%
import pandas as pd
import numpy as np

# %%
batting = pd.read_csv('Batting.csv')

# %%
batting.describe()
# Out:
#               yearID          stint              G             AB  \
# count  105861.000000  105861.000000  105861.000000  105861.000000
# mean     1965.775290       1.078773      51.214338     140.960694
# std        39.319486       0.286613      47.057599     184.433173
# min      1871.000000       1.000000       1.000000       0.000000
# 25%      1935.000000       1.000000      13.000000       4.000000
# 50%      1975.000000       1.000000      34.000000      48.000000
# 75%      2000.000000       1.000000      80.000000     229.000000
# max      2018.000000       5.000000     165.000000     716.000000
#
#                    R              H             2B             3B  \
# count  105861.000000  105861.000000  105861.000000  105861.000000
# mean       18.694212      36.861583       6.266321       1.271875
# std        28.180404      52.471260       9.666868       2.621256
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         4.000000       9.000000       1.000000       0.000000
# 75%        27.000000      57.000000       9.000000       1.000000
# max       198.000000     262.000000      67.000000      36.000000
#
#                   HR            RBI             SB            CS  \
# count  105861.000000  105105.000000  103493.000000  82320.000000
# mean        2.843209      16.968432       2.970771      1.205576
# std         6.354058      26.342342       7.687529      2.717156
# min         0.000000       0.000000       0.000000      0.000000
# 25%         0.000000       0.000000       0.000000      0.000000
# 50%         0.000000       3.000000       0.000000      0.000000
# 75%         2.000000      24.000000       2.000000      1.000000
# max        73.000000     191.000000     138.000000     42.000000
#
#                   BB             SO           IBB            HBP  \
# count  105861.000000  103761.000000  69210.000000  103044.000000
# mean       12.990431      20.577057      1.086086       1.060809
# std        20.706939      28.345666      2.750420       2.290011
# min         0.000000       0.000000      0.000000       0.000000
# 25%         0.000000       1.000000      0.000000       0.000000
# 50%         2.000000       9.000000      0.000000       0.000000
# 75%        18.000000      29.000000      1.000000       1.000000
# max       232.000000     223.000000    120.000000      51.000000
#
#                  SH            SF        GIDP
# count  99792.000000  69757.000000  80420.0000
# mean       2.252535      1.043594      2.9404
# std        4.198339      1.950372      4.7085
# min        0.000000      0.000000      0.0000
# 25%        0.000000      0.000000      0.0000
# 50%        0.000000      0.000000      0.0000
# 75%        3.000000      1.000000      4.0000
# max       67.000000     19.000000     36.0000

# %%
batting['AVG'] = batting['H']/batting['AB']
batting['Singles'] = batting['H'] - (batting['2B'] + batting['3B'] + batting['HR'])
batting['SLG'] = (batting['Singles'] + 2*batting['2B'] + 3*batting['3B'] + 4*batting['HR']) / batting['H']
batting['SLG'] = batting['SLG'].fillna(0)
batting.head()
# Out:
#     playerID  yearID  stint teamID lgID   G   AB   R   H  2B  ...  BB   SO  \
# 0  abercda01    1871      1    TRO  NaN   1    4   0   0   0  ...   0  0.0
# 1   addybo01    1871      1    RC1  NaN  25  118  30  32   6  ...   4  0.0
# 2  allisar01    1871      1    CL1  NaN  29  137  28  40   4  ...   2  5.0
# 3  allisdo01    1871      1    WS3  NaN  27  133  28  44  10  ...   0  2.0
# 4  ansonca01    1871      1    RC1  NaN  25  120  29  39  11  ...   2  1.0
#
#    IBB  HBP  SH  SF  GIDP       AVG  Singles       SLG
# 0  NaN  NaN NaN NaN   0.0  0.000000        0  0.000000
# 1  NaN  NaN NaN NaN   0.0  0.271186       26  1.187500
# 2  NaN  NaN NaN NaN   1.0  0.291971       31  1.350000
# 3  NaN  NaN NaN NaN   0.0  0.330827       30  1.454545
# 4  NaN  NaN NaN NaN   0.0  0.325000       25  1.435897
#
# [5 rows x 25 columns]

# %%
avg_batting_by_year = batting.groupby('yearID').mean()['AVG']
avg_slg_by_year = batting.groupby('yearID').mean()['SLG']

# %%
import matplotlib.pyplot as plt
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.figure_factory as ff
import cufflinks as cf
cf.set_config_file(offline=False, world_readable=True, theme='ggplot')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
plt.plot(avg_batting_by_year.index, avg_batting_by_year)
plt.title('MLB Batting Average')
plt.xlabel('Year')
plt.ylabel('Batting Average')
# Out:
# Text(0, 0.5, 'Batting Average')

# %%
trace1 = go.Scatter(x = avg_batting_by_year.index, y=avg_batting_by_year, mode = 'lines+markers', name = 'Batting Average')
data = [trace1]
layout = go.Layout(
    title=go.layout.Title(
        text='MLB Batting Average',
        xref='paper',
        x=0))
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='styling-names')
# Out:
# <div>
#
#
#             <div id="24d7ee0f-a1ae-4dfe-a984-8133b40c747c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("24d7ee0f-a1ae-4dfe-a984-8133b40c747c")) {
#                     Plotly.newPlot(
#                         '24d7ee0f-a1ae-4dfe-a984-8133b40c747c',
#                         [{"mode": "lines+markers", "name": "Batting Average", "type": "scatter", "uid": "570f8ece-508e-46e2-9c6d-35c4c0dba01a", "x": [1871, 1872, 1873, 1874, 1875, 1876, 1877, 1878, 1879, 1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], "y": [0.2543126088262979, 0.24638343354525158, 0.2515359341296079, 0.2397557849247966, 0.2181496498909367, 0.21081238771961053, 0.2329570998661328, 0.23590006738564745, 0.22398040252565857, 0.2113740335578715, 0.22954632142404566, 0.20926769094939265, 0.22315696683656144, 0.2039755978746341, 0.19830207343262504, 0.20392461392342479, 0.23226187966048445, 0.20721413509089065, 0.22930804936903842, 0.21684313517296594, 0.21721645600708142, 0.20168148291612456, 0.2521160986434287, 0.25511034386367787, 0.25291705632224687, 0.2440825565701738, 0.2540902062403745, 0.23830971068349488, 0.23894402115382948, 0.23792160301233087, 0.2293347930115087, 0.22696662045354213, 0.2145510742680888, 0.2085549442401478, 0.20493024919635625, 0.2092804307800355, 0.20109812975129834, 0.1965415377453131, 0.19952803270863523, 0.19980739544473047, 0.21375919424145476, 0.20784946406318114, 0.20610500888765407, 0.20718418554374268, 0.20315808326562126, 0.19579548853825596, 0.1937453619044518, 0.21662278917302114, 0.20994152649461295, 0.21908501403339728, 0.23056058687820113, 0.23756917531500973, 0.2354262748373781, 0.23344896177578747, 0.23705942455903734, 0.23063353901596392, 0.23994461462054517, 0.2315368068205642, 0.23252470640143325, 0.24135602952344634, 0.22310099937210476, 0.21903280750632406, 0.221205635238148, 0.22589971845636042, 0.23159115187291165, 0.22624393468032158, 0.21581265589388218, 0.228120371009984, 0.21436172484001045, 0.21283822373914738, 0.20748416961303726, 0.21025331725362514, 0.20415770525084814, 0.2095790408110795, 0.2098513582293012, 0.20086839464543024, 0.21267970896486357, 0.2119181700000764, 0.21953146518431146, 0.20876585849333418, 0.21735972839620868, 0.19345926839358743, 0.2044784098160351, 0.1935619796070084, 0.20423236290066044, 0.19712412360324447, 0.19742073138023622, 0.19853428266976125, 0.19423503613662524, 0.2006089590175246, 0.20175125136681693, 0.19790023839715185, 0.1898707019486775, 0.18504157153068426, 0.17997480276562647, 0.18893144066664797, 0.17840796923887367, 0.18105838428034374, 0.1881786843751378, 0.19076076125639446, 0.19592076227937033, 0.1876005206058006, 0.21422958857591595, 0.21670107967942911, 0.21408664092515192, 0.20844393615247964, 0.2141574615791352, 0.2133335719257242, 0.22222842359182973, 0.22225740668978594, 0.21494216104674116, 0.21628116489100235, 0.21410516092385334, 0.21576656000365502, 0.20938939559904407, 0.20955935407048965, 0.20993227289765143, 0.20115422998118063, 0.210736156570103, 0.205483857672614, 0.20089899532424127, 0.2149322923398486, 0.21960148450633038, 0.22646676910342328, 0.21913143166591922, 0.21752381656614658, 0.20816877992740884, 0.20132753996319377, 0.21161424271846824, 0.2148315550163744, 0.20253198463192046, 0.2014004990562649, 0.20538932579751024, 0.19257159754437403, 0.20339383093056324, 0.20519899860935925, 0.20790722966812378, 0.19874129962486228, 0.1949223947714029, 0.19708876253843619, 0.20236304041926068, 0.18926470254787378, 0.185103799614 ...
#                         {"title": {"text": "MLB Batting Average", "x": 0, "xref": "paper"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('24d7ee0f-a1ae-4dfe-a984-8133b40c747c');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
trace2 = go.Scatter(x = avg_slg_by_year.index, y=avg_slg_by_year, mode = 'lines+markers', name = 'Slugging Percentage')
data2 = [trace2]
layout = go.Layout(
    title=go.layout.Title(
        text='MLB Slugging Percentage',
        xref='paper',
        x=0))
fig = go.Figure(data=data2, layout=layout)
py.iplot(fig, filename='styling-names')
# Out:
# <div>
#
#
#             <div id="202250ca-2548-4aba-a4ea-1c3a7ead9fb9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("202250ca-2548-4aba-a4ea-1c3a7ead9fb9")) {
#                     Plotly.newPlot(
#                         '202250ca-2548-4aba-a4ea-1c3a7ead9fb9',
#                         [{"mode": "lines+markers", "name": "Slugging Percentage", "type": "scatter", "uid": "59b1dfb7-7c37-494f-9363-e73ffdb6e307", "x": [1871, 1872, 1873, 1874, 1875, 1876, 1877, 1878, 1879, 1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], "y": [1.2041764665931016, 1.0954715878320798, 1.0771386821586058, 1.0819588458919023, 1.1089671461139292, 1.0004948441136219, 1.1373085762370398, 1.1749343141813127, 1.1341734876925014, 1.1781434216863842, 1.1736115656721524, 1.1609620019158111, 1.1845616941157247, 1.1484991165440264, 1.1789855467733188, 1.1481382697000053, 1.2332931483855363, 1.209897278807651, 1.2112500918569225, 1.172763538593068, 1.19265673095019, 1.150719046746324, 1.2307239016785652, 1.1899038200936258, 1.2190084230734988, 1.2080407169074372, 1.219570730732549, 1.1841191113163287, 1.1892595068386556, 1.1876572081616392, 1.1672036429100423, 1.1089957257205951, 1.1314871625503269, 1.1517929151926294, 1.1468195677792417, 1.1272382707107123, 1.096795244039587, 1.09553211699786, 1.093018054831503, 1.0887047472181821, 1.102836255834191, 1.0010326037543689, 1.046180504380995, 1.081141797042324, 1.0953521730887166, 1.0577883710440816, 1.070473384121711, 1.079090416756811, 1.0575792152959345, 1.077474819671091, 1.0952335172621375, 1.1288978819317024, 1.091877339560936, 1.1114028103919866, 1.1307283856547445, 1.138515678934106, 1.1623811149010388, 1.157145468831203, 1.142341824275036, 1.2189397589962725, 1.1770303291408357, 1.1719483482343813, 1.176997905012409, 1.1799461862037615, 1.1565556026765058, 1.1605476704172928, 1.129380993812119, 1.1317416899592332, 1.1113768768188583, 1.1431079331861544, 1.1110317939471228, 1.1375945490013486, 1.0874713391527886, 1.071009235601635, 1.1149414313156836, 1.0475536545710495, 1.1221753769667064, 1.1263771786858576, 1.1635641492007975, 1.1615484449200397, 1.1835214577504256, 1.1297205322003565, 1.1657235751596686, 1.139689247136796, 1.1162505482296552, 1.1210113426953918, 1.1423944972239397, 1.1411390422872165, 1.1453572392587144, 1.1444569119695431, 1.1675633276681494, 1.1423971215986233, 1.148244315712452, 1.0720147869992125, 1.1147044472908103, 1.1191817367032155, 1.1037603750832723, 1.0995099229798653, 1.0810615016444844, 1.1141609123266467, 1.1467167937580833, 1.090975269686972, 0.9844047551949163, 0.9436414844235723, 0.9619554775915625, 0.9645078031087909, 0.9528722414266274, 0.9448775539073087, 0.9439610847684623, 0.9770473648589172, 0.9492931256097022, 0.9754881339744311, 0.9663074013653208, 0.9626647710072613, 0.9380942870811863, 0.9698650091173167, 0.9785804367414656, 0.9162264286824173, 0.9254465407620517, 0.8986450932850517, 0.8817181813324015, 0.9158277209956783, 0.9193787174602055, 0.9347777876510831, 0.8953323447463705, 0.9204498255286595, 0.939290725869266, 0.9475136741024592, 0.9440993946948644, 0.9469931628418895, 0.9468032439102384, 0.9287747858242544, 0.9185949529368306, 0.9173341770509593, 0.903988400656975, 0.9118665179748815, 0.8926224326189998, 0.8797582783579171, 0.8667939202585377, 0.8985448947542404, 0.8790618188334206, 0.8856030108683296, 0.8389044729687654, 0.8380694153347119, 0.8508658221872651, 0.8366470721011346, 0.8556232464452782, 0.8413823057397343]}],
#                         {"title": {"text": "MLB Slugging Percentage", "x": 0, "xref": "paper"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('202250ca-2548-4aba-a4ea-1c3a7ead9fb9');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
batting_100_AB = batting[batting['AB'] >= 100]
max_batting_by_year = batting_100_AB.groupby('yearID').max()['AVG']

# %%
plt.plot(max_batting_by_year.index, max_batting_by_year)
plt.title('Max Batting Average Throughout MLB for players with >= 100 AB')
plt.xlabel('Year')
plt.ylabel('Batting Average')
# Out:
# Text(0, 0.5, 'Batting Average')

# %%
hall_of_fame = pd.read_csv('HallOfFame.csv')

# %%
hall_of_fame[hall_of_fame['playerID'] == 'ansonca01']
# Out:
#       playerID  yearID     votedBy  ballots  needed  votes inducted category  \
# 17   ansonca01    1936    Veterans     78.0    59.0   39.0        N   Player
# 458  ansonca01    1939  Old Timers      NaN     NaN    NaN        Y   Player
#
#     needed_note
# 17          NaN
# 458         NaN

# %%
hall_of_fame_max = hall_of_fame.groupby('playerID').max().reset_index()
hall_of_fame_max = hall_of_fame_max[hall_of_fame_max['category'] == 'Player']
hall_of_fame_max.head()
# Out:
#     playerID  yearID          votedBy  ballots  needed  votes inducted  \
# 0  aaronha01    1982            BBWAA    415.0   312.0  406.0        Y
# 1  abbotji01    2005            BBWAA    516.0   387.0   13.0        N
# 2  adamsba01    1955  Nominating Vote    274.0   206.0   24.0        N
# 3  adamsbo03    1966            BBWAA    302.0   227.0    1.0        N
# 4  adamssp01    1960            BBWAA    269.0   202.0    1.0        N
#
#   category
# 0   Player
# 1   Player
# 2   Player
# 3   Player
# 4   Player

# %%
hall_of_fame_max[hall_of_fame_max['playerID'] == 'ansonca01']
# Out:
#      playerID  yearID   votedBy  ballots  needed  votes inducted category
# 26  ansonca01    1939  Veterans     78.0    59.0   39.0        Y   Player

# %%
mlb = batting[['playerID','yearID','teamID','AVG']]
mlb = mlb.merge(hall_of_fame_max[['playerID', 'inducted', 'category']], on = 'playerID')

# %%
mlb[mlb['inducted'] == 'Y']['AVG'].mean()
# Out:
# 0.2604020338923422

# %%
mlb['AVG'].mean()
# Out:
# 0.24102430144080078

# %%
mlb.head()
# Out:
#     playerID  yearID teamID       AVG inducted category
# 0  allisdo01    1871    WS3  0.330827        N   Player
# 1  allisdo01    1872    TRO  0.307018        N   Player
# 2  allisdo01    1872    BR1  0.337349        N   Player
# 3  allisdo01    1873    ELI  0.300000        N   Player
# 4  allisdo01    1873    NY2  0.208333        N   Player

# %%
import seaborn as sns

# %%
mlb['AVG'] = mlb['AVG'].fillna(0)

sns.distplot(mlb[mlb['inducted'] == 'N']['AVG'])
sns.distplot(mlb[mlb['inducted'] == 'Y']['AVG'])

# %%
# These lines help load your submission for grading.
from client.api.notebook import Notebook
ok = Notebook('final-project.ok')
_ = ok.auth(inline=True)

# %%
_ = ok.submit()
